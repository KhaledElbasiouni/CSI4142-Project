# %% [markdown]
# ## Labour Force Characteristics
# ### Importing Data

# %%
import pandas as pd
labour_df = pd.read_csv('data/labour_force_characteristics.csv')
labour_df[:10]
# Out:
#    REF_DATE     GEO           DGUID Labour force characteristics  \
# 0      1990  Canada  2016A000011124                   Population
# 1      1990  Canada  2016A000011124                   Population
# 2      1990  Canada  2016A000011124                   Population
# 3      1990  Canada  2016A000011124                   Population
# 4      1990  Canada  2016A000011124                   Population
# 5      1990  Canada  2016A000011124                   Population
# 6      1990  Canada  2016A000011124                   Population
# 7      1990  Canada  2016A000011124                   Population
# 8      1990  Canada  2016A000011124                   Population
# 9      1990  Canada  2016A000011124                   Population
#
#             Educational degree         Sex          Age group      UOM  \
# 0  Total, all education levels  Both sexes  15 years and over  Persons
# 1  Total, all education levels  Both sexes     15 to 24 years  Persons
# 2  Total, all education levels  Both sexes  25 years and over  Persons
# 3  Total, all education levels  Both sexes     25 to 54 years  Persons
# 4  Total, all education levels  Both sexes  55 years and over  Persons
# 5  Total, all education levels  Both sexes     55 to 64 years  Persons
# 6  Total, all education levels  Both sexes  65 years and over  Persons
# 7  Total, all education levels       Males  15 years and over  Persons
# 8  Total, all education levels       Males     15 to 24 years  Persons
# 9  Total, all education levels       Males  25 years and over  Persons
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE    VALUE STATUS  \
# 0     249     thousands          3  v55009060  1.1.1.1.1  21214.7    NaN
# 1     249     thousands          3  v55009061  1.1.1.1.2   3924.9    NaN
# 2     249     thousands          3  v55009062  1.1.1.1.3  17289.8    NaN
# 3     249     thousands          3  v55009063  1.1.1.1.4  12029.9    NaN
# 4     249     thousands          3  v55009064  1.1.1.1.5   5259.9    NaN
# 5     249     thousands          3  v55009065  1.1.1.1.6   2379.7    NaN
# 6     249     thousands          3  v55009066  1.1.1.1.7   2880.2    NaN
# 7     249     thousands          3  v55009067  1.1.1.2.1  10410.2    NaN
# 8     249     thousands          3  v55009068  1.1.1.2.2   1995.9    NaN
# 9     249     thousands          3  v55009069  1.1.1.2.3   8414.3    NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         1
# 1     NaN         NaN         1
# 2     NaN         NaN         1
# 3     NaN         NaN         1
# 4     NaN         NaN         1
# 5     NaN         NaN         1
# 6     NaN         NaN         1
# 7     NaN         NaN         1
# 8     NaN         NaN         1
# 9     NaN         NaN         1

# %%
labour_df.dtypes
# Out:
# REF_DATE                          int64
# GEO                              object
# DGUID                            object
# Labour force characteristics     object
# Educational degree               object
# Sex                              object
# Age group                        object
# UOM                              object
# UOM_ID                            int64
# SCALAR_FACTOR                    object
# SCALAR_ID                         int64
# VECTOR                           object
# COORDINATE                       object
# VALUE                           float64
# STATUS                           object
# SYMBOL                          float64
# TERMINATED                      float64
# DECIMALS                          int64
# dtype: object

# %%
'number of rows=%d' % labour_df.shape[0]
# Out:
# 'number of rows=785400'

# %% [markdown]
# ### Dropping Unnecessary Columns

# %%
labour_df[labour_df.columns.values].apply(lambda x: x.unique())
# Out:
# REF_DATE                        [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# GEO                             [Canada, Newfoundland and Labrador, Prince Edw...
# DGUID                           [2016A000011124, 2016A000210, 2016A000211, 201...
# Labour force characteristics    [Population, Labour force, Employment, Full-ti...
# Educational degree              [Total, all education levels, No degree, certi...
# Sex                                                  [Both sexes, Males, Females]
# Age group                       [15 years and over, 15 to 24 years, 25 years a...
# UOM                                                         [Persons, Percentage]
# UOM_ID                                                                 [249, 242]
# SCALAR_FACTOR                                                  [thousands, units]
# SCALAR_ID                                                                  [3, 0]
# VECTOR                          [v55009060, v55009061, v55009062, v55009063, v...
# COORDINATE                      [1.1.1.1.1, 1.1.1.1.2, 1.1.1.1.3, 1.1.1.1.4, 1...
# VALUE                           [21214.7, 3924.9, 17289.8, 12029.9, 5259.9, 23...
# STATUS                                                                   [nan, x]
# SYMBOL                                                                      [nan]
# TERMINATED                                                                  [nan]
# DECIMALS                                                                      [1]
# dtype: object

# %%
labour_df = labour_df.drop(columns=['DGUID', 'UOM_ID', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'])
labour_df
# Out:
#         REF_DATE               GEO Labour force characteristics  \
# 0           1990            Canada                   Population
# 1           1990            Canada                   Population
# 2           1990            Canada                   Population
# 3           1990            Canada                   Population
# 4           1990            Canada                   Population
# ...          ...               ...                          ...
# 785395      2023  British Columbia              Employment rate
# 785396      2023  British Columbia              Employment rate
# 785397      2023  British Columbia              Employment rate
# 785398      2023  British Columbia              Employment rate
# 785399      2023  British Columbia              Employment rate
#
#                  Educational degree         Sex          Age group  \
# 0       Total, all education levels  Both sexes  15 years and over
# 1       Total, all education levels  Both sexes     15 to 24 years
# 2       Total, all education levels  Both sexes  25 years and over
# 3       Total, all education levels  Both sexes     25 to 54 years
# 4       Total, all education levels  Both sexes  55 years and over
# ...                             ...         ...                ...
# 785395      Above bachelor's degree     Females  25 years and over
# 785396      Above bachelor's degree     Females     25 to 54 years
# 785397      Above bachelor's degree     Females  55 years and over
# 785398      Above bachelor's degree     Females     55 to 64 years
# 785399      Above bachelor's degree     Females  65 years and over
#
#                UOM SCALAR_FACTOR    VALUE
# 0          Persons     thousands  21214.7
# 1          Persons     thousands   3924.9
# 2          Persons     thousands  17289.8
# 3          Persons     thousands  12029.9
# 4          Persons     thousands   5259.9
# ...            ...           ...      ...
# 785395  Percentage         units     74.7
# 785396  Percentage         units     88.6
# 785397  Percentage         units     43.9
# 785398  Percentage         units     70.9
# 785399  Percentage         units     20.8
#
# [785400 rows x 9 columns]

# %% [markdown]
# ### Column Filtering
# The `UOM` column has two unique values: `Persons` and `Percentage`. We only care about the percentage of graduates per age group, degree, and labour force characteristic. Thus, we filter for rows where `UOM == "Persons"`.

# %%
labour_df = labour_df.query('UOM == "Persons"')
if len(labour_df['UOM'].unique()) == 1:
  labour_df = labour_df.drop(columns=['UOM'])
labour_df
# Out:
#         REF_DATE               GEO Labour force characteristics  \
# 0           1990            Canada                   Population
# 1           1990            Canada                   Population
# 2           1990            Canada                   Population
# 3           1990            Canada                   Population
# 4           1990            Canada                   Population
# ...          ...               ...                          ...
# 784765      2023  British Columbia          Not in labour force
# 784766      2023  British Columbia          Not in labour force
# 784767      2023  British Columbia          Not in labour force
# 784768      2023  British Columbia          Not in labour force
# 784769      2023  British Columbia          Not in labour force
#
#                  Educational degree         Sex          Age group  \
# 0       Total, all education levels  Both sexes  15 years and over
# 1       Total, all education levels  Both sexes     15 to 24 years
# 2       Total, all education levels  Both sexes  25 years and over
# 3       Total, all education levels  Both sexes     25 to 54 years
# 4       Total, all education levels  Both sexes  55 years and over
# ...                             ...         ...                ...
# 784765      Above bachelor's degree     Females  25 years and over
# 784766      Above bachelor's degree     Females     25 to 54 years
# 784767      Above bachelor's degree     Females  55 years and over
# 784768      Above bachelor's degree     Females     55 to 64 years
# 784769      Above bachelor's degree     Females  65 years and over
#
#        SCALAR_FACTOR    VALUE
# 0          thousands  21214.7
# 1          thousands   3924.9
# 2          thousands  17289.8
# 3          thousands  12029.9
# 4          thousands   5259.9
# ...              ...      ...
# 784765     thousands     50.5
# 784766     thousands     12.5
# 784767     thousands     37.9
# 784768     thousands      7.8
# 784769     thousands     30.1
#
# [549780 rows x 8 columns]

# %% [markdown]
# Additionally, since the `SCALAR_FACTOR` column is dependent on the `UOM` column, it now has a cardinality of one (df above: `thousands`). We can drop the `SCALAR_FACTOR` column.

# %%
if len(labour_df['SCALAR_FACTOR'].unique()) == 1:
  labour_df = labour_df.drop(columns=['SCALAR_FACTOR'])
labour_df
# Out:
#         REF_DATE               GEO Labour force characteristics  \
# 0           1990            Canada                   Population
# 1           1990            Canada                   Population
# 2           1990            Canada                   Population
# 3           1990            Canada                   Population
# 4           1990            Canada                   Population
# ...          ...               ...                          ...
# 784765      2023  British Columbia          Not in labour force
# 784766      2023  British Columbia          Not in labour force
# 784767      2023  British Columbia          Not in labour force
# 784768      2023  British Columbia          Not in labour force
# 784769      2023  British Columbia          Not in labour force
#
#                  Educational degree         Sex          Age group    VALUE
# 0       Total, all education levels  Both sexes  15 years and over  21214.7
# 1       Total, all education levels  Both sexes     15 to 24 years   3924.9
# 2       Total, all education levels  Both sexes  25 years and over  17289.8
# 3       Total, all education levels  Both sexes     25 to 54 years  12029.9
# 4       Total, all education levels  Both sexes  55 years and over   5259.9
# ...                             ...         ...                ...      ...
# 784765      Above bachelor's degree     Females  25 years and over     50.5
# 784766      Above bachelor's degree     Females     25 to 54 years     12.5
# 784767      Above bachelor's degree     Females  55 years and over     37.9
# 784768      Above bachelor's degree     Females     55 to 64 years      7.8
# 784769      Above bachelor's degree     Females  65 years and over     30.1
#
# [549780 rows x 7 columns]

# %% [markdown]
# The value is now in thousands as explained above. We will now multiply the value to make sure the data is consistent among the other dataframes.

# %%
labour_df['VALUE'] = labour_df['VALUE'].apply(lambda x: x * 1000)
labour_df = labour_df.fillna(0)
labour_df['VALUE'] = labour_df['VALUE'].astype('int64')
labour_df
# Out:
#         REF_DATE               GEO Labour force characteristics  \
# 0           1990            Canada                   Population
# 1           1990            Canada                   Population
# 2           1990            Canada                   Population
# 3           1990            Canada                   Population
# 4           1990            Canada                   Population
# ...          ...               ...                          ...
# 784765      2023  British Columbia          Not in labour force
# 784766      2023  British Columbia          Not in labour force
# 784767      2023  British Columbia          Not in labour force
# 784768      2023  British Columbia          Not in labour force
# 784769      2023  British Columbia          Not in labour force
#
#                  Educational degree         Sex          Age group     VALUE
# 0       Total, all education levels  Both sexes  15 years and over  21214700
# 1       Total, all education levels  Both sexes     15 to 24 years   3924900
# 2       Total, all education levels  Both sexes  25 years and over  17289800
# 3       Total, all education levels  Both sexes     25 to 54 years  12029900
# 4       Total, all education levels  Both sexes  55 years and over   5259900
# ...                             ...         ...                ...       ...
# 784765      Above bachelor's degree     Females  25 years and over     50500
# 784766      Above bachelor's degree     Females     25 to 54 years     12500
# 784767      Above bachelor's degree     Females  55 years and over     37900
# 784768      Above bachelor's degree     Females     55 to 64 years      7800
# 784769      Above bachelor's degree     Females  65 years and over     30100
#
# [549780 rows x 7 columns]

# %% [markdown]
# The dataframe includes information for each province in Canada, but in order to satisfy the requirements of the other dataframes, we will drop the column.

# %%
labour_df = labour_df.query('GEO == "Canada"')
if len(labour_df['GEO'].unique()) == 1:
  labour_df = labour_df.drop(columns=['GEO'])
labour_df
# Out:
#         REF_DATE Labour force characteristics           Educational degree  \
# 0           1990                   Population  Total, all education levels
# 1           1990                   Population  Total, all education levels
# 2           1990                   Population  Total, all education levels
# 3           1990                   Population  Total, all education levels
# 4           1990                   Population  Total, all education levels
# ...          ...                          ...                          ...
# 763765      2023          Not in labour force      Above bachelor's degree
# 763766      2023          Not in labour force      Above bachelor's degree
# 763767      2023          Not in labour force      Above bachelor's degree
# 763768      2023          Not in labour force      Above bachelor's degree
# 763769      2023          Not in labour force      Above bachelor's degree
#
#                Sex          Age group     VALUE
# 0       Both sexes  15 years and over  21214700
# 1       Both sexes     15 to 24 years   3924900
# 2       Both sexes  25 years and over  17289800
# 3       Both sexes     25 to 54 years  12029900
# 4       Both sexes  55 years and over   5259900
# ...            ...                ...       ...
# 763765     Females  25 years and over    355500
# 763766     Females     25 to 54 years    106200
# 763767     Females  55 years and over    249300
# 763768     Females     55 to 64 years     55900
# 763769     Females  65 years and over    193400
#
# [49980 rows x 6 columns]

# %% [markdown]
# We can include only the age groups that are not aggregates. In other words, they don't have `x years and over` in their name.

# %%
labour_df = labour_df.query('`Age group` == "15 to 24 years" or `Age group` == "25 to 54 years" or `Age group` == "55 to 64 years"')
labour_df
# Out:
#         REF_DATE Labour force characteristics           Educational degree  \
# 1           1990                   Population  Total, all education levels
# 3           1990                   Population  Total, all education levels
# 5           1990                   Population  Total, all education levels
# 8           1990                   Population  Total, all education levels
# 10          1990                   Population  Total, all education levels
# ...          ...                          ...                          ...
# 763759      2023          Not in labour force      Above bachelor's degree
# 763761      2023          Not in labour force      Above bachelor's degree
# 763764      2023          Not in labour force      Above bachelor's degree
# 763766      2023          Not in labour force      Above bachelor's degree
# 763768      2023          Not in labour force      Above bachelor's degree
#
#                Sex       Age group     VALUE
# 1       Both sexes  15 to 24 years   3924900
# 3       Both sexes  25 to 54 years  12029900
# 5       Both sexes  55 to 64 years   2379700
# 8            Males  15 to 24 years   1995900
# 10           Males  25 to 54 years   6013900
# ...            ...             ...       ...
# 763759       Males  25 to 54 years     42300
# 763761       Males  55 to 64 years     42500
# 763764     Females  15 to 24 years      3500
# 763766     Females  25 to 54 years    106200
# 763768     Females  55 to 64 years     55900
#
# [21420 rows x 6 columns]

# %% [markdown]
# We don't care about any of the labour force characteristics except for `Population`, `Employment`, and `Unemployment`.

# %%
labour_df = labour_df.query('`Labour force characteristics` == "Population" or `Labour force characteristics` == "Employment" or `Labour force characteristics` == "Unemployment"')
labour_df
# Out:
#         REF_DATE Labour force characteristics           Educational degree  \
# 1           1990                   Population  Total, all education levels
# 3           1990                   Population  Total, all education levels
# 5           1990                   Population  Total, all education levels
# 8           1990                   Population  Total, all education levels
# 10          1990                   Population  Total, all education levels
# ...          ...                          ...                          ...
# 763549      2023                 Unemployment      Above bachelor's degree
# 763551      2023                 Unemployment      Above bachelor's degree
# 763554      2023                 Unemployment      Above bachelor's degree
# 763556      2023                 Unemployment      Above bachelor's degree
# 763558      2023                 Unemployment      Above bachelor's degree
#
#                Sex       Age group     VALUE
# 1       Both sexes  15 to 24 years   3924900
# 3       Both sexes  25 to 54 years  12029900
# 5       Both sexes  55 to 64 years   2379700
# 8            Males  15 to 24 years   1995900
# 10           Males  25 to 54 years   6013900
# ...            ...             ...       ...
# 763549       Males  25 to 54 years     32000
# 763551       Males  55 to 64 years      6500
# 763554     Females  15 to 24 years      2500
# 763556     Females  25 to 54 years     41900
# 763558     Females  55 to 64 years      7200
#
# [9180 rows x 6 columns]

# %% [markdown]
# We want to have only information after `2000`.

# %%
labour_df = labour_df[labour_df['REF_DATE'] >= 2000]
labour_df
# Out:
#         REF_DATE Labour force characteristics           Educational degree  \
# 231001      2000                   Population  Total, all education levels
# 231003      2000                   Population  Total, all education levels
# 231005      2000                   Population  Total, all education levels
# 231008      2000                   Population  Total, all education levels
# 231010      2000                   Population  Total, all education levels
# ...          ...                          ...                          ...
# 763549      2023                 Unemployment      Above bachelor's degree
# 763551      2023                 Unemployment      Above bachelor's degree
# 763554      2023                 Unemployment      Above bachelor's degree
# 763556      2023                 Unemployment      Above bachelor's degree
# 763558      2023                 Unemployment      Above bachelor's degree
#
#                Sex       Age group     VALUE
# 231001  Both sexes  15 to 24 years   4067900
# 231003  Both sexes  25 to 54 years  13687300
# 231005  Both sexes  55 to 64 years   2765500
# 231008       Males  15 to 24 years   2081100
# 231010       Males  25 to 54 years   6831700
# ...            ...             ...       ...
# 763549       Males  25 to 54 years     32000
# 763551       Males  55 to 64 years      6500
# 763554     Females  15 to 24 years      2500
# 763556     Females  25 to 54 years     41900
# 763558     Females  55 to 64 years      7200
#
# [6480 rows x 6 columns]

# %% [markdown]
# A lot of the aggregates included in this dataframe are not needed and will mess up the fact table. Thus, we can remove the aggregates for the `Sex` column, and `Educational degree` column.

# %%
labour_df = labour_df.query('`Educational degree` != "Total, all education levels"')
labour_df = labour_df.query('Sex != "Both sexes"')
labour_df
# Out:
#         REF_DATE Labour force characteristics  \
# 231029      2000                   Population
# 231031      2000                   Population
# 231033      2000                   Population
# 231036      2000                   Population
# 231038      2000                   Population
# ...          ...                          ...
# 763549      2023                 Unemployment
# 763551      2023                 Unemployment
# 763554      2023                 Unemployment
# 763556      2023                 Unemployment
# 763558      2023                 Unemployment
#
#                        Educational degree      Sex       Age group    VALUE
# 231029  No degree, certificate or diploma    Males  15 to 24 years   943600
# 231031  No degree, certificate or diploma    Males  25 to 54 years  1232300
# 231033  No degree, certificate or diploma    Males  55 to 64 years   486000
# 231036  No degree, certificate or diploma  Females  15 to 24 years   817100
# 231038  No degree, certificate or diploma  Females  25 to 54 years  1093700
# ...                                   ...      ...             ...      ...
# 763549            Above bachelor's degree    Males  25 to 54 years    32000
# 763551            Above bachelor's degree    Males  55 to 64 years     6500
# 763554            Above bachelor's degree  Females  15 to 24 years     2500
# 763556            Above bachelor's degree  Females  25 to 54 years    41900
# 763558            Above bachelor's degree  Females  55 to 64 years     7200
#
# [3888 rows x 6 columns]

# %% [markdown]
# Finally, we can rename our dataframe and we will be done cleaning the dataframe.

# %%
labour_df.rename(columns={'REF_DATE': 'date', 'Labour force characteristics': 'labour_force', 'Educational degree': 'education', 'Sex': 'sex', 'Age group': 'age_group', 'VALUE': 'value'}, inplace=True)
labour_df
# Out:
#         date  labour_force                          education      sex  \
# 231029  2000    Population  No degree, certificate or diploma    Males
# 231031  2000    Population  No degree, certificate or diploma    Males
# 231033  2000    Population  No degree, certificate or diploma    Males
# 231036  2000    Population  No degree, certificate or diploma  Females
# 231038  2000    Population  No degree, certificate or diploma  Females
# ...      ...           ...                                ...      ...
# 763549  2023  Unemployment            Above bachelor's degree    Males
# 763551  2023  Unemployment            Above bachelor's degree    Males
# 763554  2023  Unemployment            Above bachelor's degree  Females
# 763556  2023  Unemployment            Above bachelor's degree  Females
# 763558  2023  Unemployment            Above bachelor's degree  Females
#
#              age_group    value
# 231029  15 to 24 years   943600
# 231031  25 to 54 years  1232300
# 231033  55 to 64 years   486000
# 231036  15 to 24 years   817100
# 231038  25 to 54 years  1093700
# ...                ...      ...
# 763549  25 to 54 years    32000
# 763551  55 to 64 years     6500
# 763554  15 to 24 years     2500
# 763556  25 to 54 years    41900
# 763558  55 to 64 years     7200
#
# [3888 rows x 6 columns]
