# %% [markdown]
# # Employment/Unemployment By Industry

# %% [markdown]
# ### Importing Data

# %%
import pandas as pd
# Reading the csv files into dataframes
df = pd.read_csv('data/employment-by-industry.csv')
df.head()
# Out:
#    REF_DATE     GEO           DGUID Labour force characteristics  \
# 0      1976  Canada  2016A000011124                 Labour force
# 1      1976  Canada  2016A000011124                 Labour force
# 2      1976  Canada  2016A000011124                 Labour force
# 3      1976  Canada  2016A000011124                 Labour force
# 4      1976  Canada  2016A000011124                 Labour force
#
#   North American Industry Classification System (NAICS)         Sex  \
# 0                              Total, all industries     Both sexes
# 1                              Total, all industries     Both sexes
# 2                              Total, all industries     Both sexes
# 3                              Total, all industries     Both sexes
# 4                              Total, all industries          Males
#
#            Age group      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR  \
# 0  15 years and over  Persons     249     thousands          3   v2363353
# 1     15 to 24 years  Persons     249     thousands          3  v19668072
# 2     25 to 54 years  Persons     249     thousands          3  v19668073
# 3  55 years and over  Persons     249     thousands          3  v19668074
# 4  15 years and over  Persons     249     thousands          3   v2363523
#
#   COORDINATE    VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0  1.1.1.1.1  10491.3    NaN     NaN         NaN         1
# 1  1.1.1.1.2   2891.9    NaN     NaN         NaN         1
# 2  1.1.1.1.3   6410.7    NaN     NaN         NaN         1
# 3  1.1.1.1.4   1188.7    NaN     NaN         NaN         1
# 4  1.1.1.2.1   6549.6    NaN     NaN         NaN         1

# %% [markdown]
# ### Filter Data

# %%
df = df[(df['REF_DATE'] >= 2000) & (df['REF_DATE'] < 2021) & (df["GEO"] == "Canada") & (df["UOM"] == "Persons")]
df = df[df["Labour force characteristics"].isin(["Employment", "Unemployment"])]
df = df[df["Sex"].isin(["Males", "Females"])]
df.head()
# Out:
#         REF_DATE     GEO           DGUID Labour force characteristics  \
# 460504      2000  Canada  2016A000011124                   Employment
# 460505      2000  Canada  2016A000011124                   Employment
# 460506      2000  Canada  2016A000011124                   Employment
# 460507      2000  Canada  2016A000011124                   Employment
# 460508      2000  Canada  2016A000011124                   Employment
#
#        North American Industry Classification System (NAICS)      Sex  \
# 460504                              Total, all industries       Males
# 460505                              Total, all industries       Males
# 460506                              Total, all industries       Males
# 460507                              Total, all industries       Males
# 460508                              Total, all industries     Females
#
#                 Age group      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 460504  15 years and over  Persons     249     thousands          3
# 460505     15 to 24 years  Persons     249     thousands          3
# 460506     25 to 54 years  Persons     249     thousands          3
# 460507  55 years and over  Persons     249     thousands          3
# 460508  15 years and over  Persons     249     thousands          3
#
#            VECTOR COORDINATE   VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 460504   v2363552  1.2.1.2.1  7971.0    NaN     NaN         NaN         1
# 460505  v19668336  1.2.1.2.2  1180.5    NaN     NaN         NaN         1
# 460506  v19668337  1.2.1.2.3  5863.6    NaN     NaN         NaN         1
# 460507  v19668338  1.2.1.2.4   926.9    NaN     NaN         NaN         1
# 460508   v2363722  1.2.1.3.1  6789.1    NaN     NaN         NaN         1

# %% [markdown]
# ### Select Required Columns

# %%
df = df[["REF_DATE", "Labour force characteristics", "North American Industry Classification System (NAICS)", "Sex","Age group", "VALUE"]]

df.head()
# Out:
#         REF_DATE Labour force characteristics  \
# 460504      2000                   Employment
# 460505      2000                   Employment
# 460506      2000                   Employment
# 460507      2000                   Employment
# 460508      2000                   Employment
#
#        North American Industry Classification System (NAICS)      Sex  \
# 460504                              Total, all industries       Males
# 460505                              Total, all industries       Males
# 460506                              Total, all industries       Males
# 460507                              Total, all industries       Males
# 460508                              Total, all industries     Females
#
#                 Age group   VALUE
# 460504  15 years and over  7971.0
# 460505     15 to 24 years  1180.5
# 460506     25 to 54 years  5863.6
# 460507  55 years and over   926.9
# 460508  15 years and over  6789.1

# %% [markdown]
# ### Multiply Value By Scalar_Factor

# %% [markdown]
# ### Rename Columns

# %%
df.rename(columns={'REF_DATE': 'Date', 'North American Industry Classification System (NAICS)': 'NAICS','VALUE': 'Value', 'Sex': 'Gender', "Labour force characteristics": "Labour Force Characteristics", "Age group": "Age Group"}, inplace=True)
df
# Out:
#         Date Labour Force Characteristics                    NAICS   Gender  \
# 460504  2000                   Employment    Total, all industries    Males
# 460505  2000                   Employment    Total, all industries    Males
# 460506  2000                   Employment    Total, all industries    Males
# 460507  2000                   Employment    Total, all industries    Males
# 460508  2000                   Employment    Total, all industries  Females
# ...      ...                          ...                      ...      ...
# 910651  2020                 Unemployment  Unclassified industries    Males
# 910652  2020                 Unemployment  Unclassified industries  Females
# 910653  2020                 Unemployment  Unclassified industries  Females
# 910654  2020                 Unemployment  Unclassified industries  Females
# 910655  2020                 Unemployment  Unclassified industries  Females
#
#                 Age Group   Value
# 460504  15 years and over  7971.0
# 460505     15 to 24 years  1180.5
# 460506     25 to 54 years  5863.6
# 460507  55 years and over   926.9
# 460508  15 years and over  6789.1
# ...                   ...     ...
# 910651  55 years and over    44.0
# 910652  15 years and over   230.3
# 910653     15 to 24 years    85.1
# 910654     25 to 54 years   117.2
# 910655  55 years and over    28.0
#
# [9576 rows x 6 columns]

# %% [markdown]
# ### Change "Employment" and "Unemployment" to "Employed" and "Unemployed"

# %%
df.loc[df["Labour Force Characteristics"] == "Employment", "Labour Force Characteristics"] = 'Employed'
df.loc[df["Labour Force Characteristics"] == "Unemployment", "Labour Force Characteristics"] = 'Unemployed'
df
# Out:
#         Date Labour Force Characteristics                    NAICS   Gender  \
# 460504  2000                     Employed    Total, all industries    Males
# 460505  2000                     Employed    Total, all industries    Males
# 460506  2000                     Employed    Total, all industries    Males
# 460507  2000                     Employed    Total, all industries    Males
# 460508  2000                     Employed    Total, all industries  Females
# ...      ...                          ...                      ...      ...
# 910651  2020                   Unemployed  Unclassified industries    Males
# 910652  2020                   Unemployed  Unclassified industries  Females
# 910653  2020                   Unemployed  Unclassified industries  Females
# 910654  2020                   Unemployed  Unclassified industries  Females
# 910655  2020                   Unemployed  Unclassified industries  Females
#
#                 Age Group   Value
# 460504  15 years and over  7971.0
# 460505     15 to 24 years  1180.5
# 460506     25 to 54 years  5863.6
# 460507  55 years and over   926.9
# 460508  15 years and over  6789.1
# ...                   ...     ...
# 910651  55 years and over    44.0
# 910652  15 years and over   230.3
# 910653     15 to 24 years    85.1
# 910654     25 to 54 years   117.2
# 910655  55 years and over    28.0
#
# [9576 rows x 6 columns]

# %% [markdown]
# ### Reset Index

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#       Date Labour Force Characteristics                    NAICS   Gender  \
# 0     2000                     Employed    Total, all industries    Males
# 1     2000                     Employed    Total, all industries    Males
# 2     2000                     Employed    Total, all industries    Males
# 3     2000                     Employed    Total, all industries    Males
# 4     2000                     Employed    Total, all industries  Females
# ...    ...                          ...                      ...      ...
# 9571  2020                   Unemployed  Unclassified industries    Males
# 9572  2020                   Unemployed  Unclassified industries  Females
# 9573  2020                   Unemployed  Unclassified industries  Females
# 9574  2020                   Unemployed  Unclassified industries  Females
# 9575  2020                   Unemployed  Unclassified industries  Females
#
#               Age Group   Value
# 0     15 years and over  7971.0
# 1        15 to 24 years  1180.5
# 2        25 to 54 years  5863.6
# 3     55 years and over   926.9
# 4     15 years and over  6789.1
# ...                 ...     ...
# 9571  55 years and over    44.0
# 9572  15 years and over   230.3
# 9573     15 to 24 years    85.1
# 9574     25 to 54 years   117.2
# 9575  55 years and over    28.0
#
# [9576 rows x 6 columns]

# %% [markdown]
# ### Filter NAICS To Remove Aggregated Industries

# %%
df = df[(df['NAICS'].str.contains(r'\['))]
df = df[~df["NAICS"].isin(["Forestry, fishing, mining, quarrying, oil and gas [21, 113-114, 1153, 2100]", "Finance, insurance, real estate, rental and leasing [52, 53]", "Wholesale and retail trade [41, 44-45]"])]
df.reset_index(drop=True, inplace=True)

for val in df["NAICS"].unique():
    print(val)
# Out:
# Agriculture [111-112, 1100, 1151-1152]
# Forestry and logging and support activities for forestry [113, 1153]
# Fishing, hunting and trapping [114]
# Mining, quarrying, and oil and gas extraction [21, 2100]
# Utilities [22]
# Construction [23]
# Manufacturing [31-33]
# Durables [321, 327, 331-339]
# Non-durables [311-316, 322-326]
# Wholesale trade [41]
# Retail trade [44-45]
# Transportation and warehousing [48-49]
# Finance and insurance [52]
# Real estate and rental and leasing [53]
# Professional, scientific and technical services [54]
# Business, building and other support services [55, 56]
# Educational services [61]
# Health care and social assistance [62]
# Information, culture and recreation [51, 71]
# Accommodation and food services [72]
# Other services (except public administration) [81]
# Public administration [91]

# %%
df
# Out:
#       Date Labour Force Characteristics  \
# 0     2000                     Employed
# 1     2000                     Employed
# 2     2000                     Employed
# 3     2000                     Employed
# 4     2000                     Employed
# ...    ...                          ...
# 7387  2020                   Unemployed
# 7388  2020                   Unemployed
# 7389  2020                   Unemployed
# 7390  2020                   Unemployed
# 7391  2020                   Unemployed
#
#                                        NAICS   Gender          Age Group  \
# 0     Agriculture [111-112, 1100, 1151-1152]    Males  15 years and over
# 1     Agriculture [111-112, 1100, 1151-1152]    Males     15 to 24 years
# 2     Agriculture [111-112, 1100, 1151-1152]    Males     25 to 54 years
# 3     Agriculture [111-112, 1100, 1151-1152]    Males  55 years and over
# 4     Agriculture [111-112, 1100, 1151-1152]  Females  15 years and over
# ...                                      ...      ...                ...
# 7387              Public administration [91]    Males  55 years and over
# 7388              Public administration [91]  Females  15 years and over
# 7389              Public administration [91]  Females     15 to 24 years
# 7390              Public administration [91]  Females     25 to 54 years
# 7391              Public administration [91]  Females  55 years and over
#
#       Value
# 0     258.9
# 1      44.0
# 2     142.6
# 3      72.3
# 4     112.4
# ...     ...
# 7387    2.8
# 7388   17.4
# 7389    5.0
# 7390    6.8
# 7391    5.5
#
# [7392 rows x 6 columns]

# %%
replace_with_agriculture = "Agriculture, forestry, fishing and hunting [11]"
replace_with_mining = "Mining, quarrying, and oil and gas extraction [21]"
df['NAICS'].replace({'Agriculture [111-112, 1100, 1151-1152]':replace_with_agriculture,'Forestry and logging and support activities for forestry [113, 1153]': replace_with_agriculture, 'Fishing, hunting and trapping [114]': replace_with_agriculture , "Mining, quarrying, and oil and gas extraction [21, 2100]": replace_with_mining}, inplace=True)

df = df.groupby(["Date","Labour Force Characteristics","NAICS", "Gender", "Age Group",], as_index=False)['Value'].sum()

arr = ["Non-durables [311-316, 322-326]",
"Durables [321, 327, 331-339]", "Wholesale trade [41]"]

df = df.query('NAICS not in @arr')

for val in df["NAICS"].unique():
    print(val)
# Out:
# Accommodation and food services [72]
# Agriculture, forestry, fishing and hunting [11]
# Business, building and other support services [55, 56]
# Construction [23]
# Educational services [61]
# Finance and insurance [52]
# Health care and social assistance [62]
# Information, culture and recreation [51, 71]
# Manufacturing [31-33]
# Mining, quarrying, and oil and gas extraction [21]
# Other services (except public administration) [81]
# Professional, scientific and technical services [54]
# Public administration [91]
# Real estate and rental and leasing [53]
# Retail trade [44-45]
# Transportation and warehousing [48-49]
# Utilities [22]

# %%
df
# Out:
#       Date Labour Force Characteristics                                 NAICS  \
# 0     2000                     Employed  Accommodation and food services [72]
# 1     2000                     Employed  Accommodation and food services [72]
# 2     2000                     Employed  Accommodation and food services [72]
# 3     2000                     Employed  Accommodation and food services [72]
# 4     2000                     Employed  Accommodation and food services [72]
# ...    ...                          ...                                   ...
# 6707  2020                   Unemployed                        Utilities [22]
# 6708  2020                   Unemployed                        Utilities [22]
# 6709  2020                   Unemployed                        Utilities [22]
# 6710  2020                   Unemployed                        Utilities [22]
# 6711  2020                   Unemployed                        Utilities [22]
#
#        Gender          Age Group  Value
# 0     Females     15 to 24 years  235.0
# 1     Females  15 years and over  558.2
# 2     Females     25 to 54 years  285.4
# 3     Females  55 years and over   37.7
# 4       Males     15 to 24 years  160.9
# ...       ...                ...    ...
# 6707  Females  55 years and over    0.0
# 6708    Males     15 to 24 years    0.0
# 6709    Males  15 years and over    2.1
# 6710    Males     25 to 54 years    0.0
# 6711    Males  55 years and over    0.0
#
# [5712 rows x 6 columns]

# %%
df.dtypes
# Out:
# Date                              int64
# Labour Force Characteristics     object
# NAICS                            object
# Gender                           object
# Age Group                        object
# Value                           float64
# dtype: object

# %% [markdown]
# ### Find Empty Values

# %% [markdown]
# ### Find Averages For Different Groups and Replace 0.0/Empty/Missing Values

# %%
df = df.fillna(0.0)
temp = df
temp = temp.drop(columns=["Date"])
temp.reset_index(drop=True, inplace=True)

empty_rows = temp.query('Value == 0.0').groupby(["Labour Force Characteristics", "NAICS", "Gender", "Age Group"])

empty_rows_list = empty_rows.apply(lambda x: x).values.tolist()
for row in empty_rows_list:

    query_df = df[(df['Value'] != 0.0) & (df['Labour Force Characteristics'] == row[0]) * (df["NAICS"] == row[1]) & (df["Gender"] == row[2]) & (df["Age Group"] == row[3])]
    if (not query_df.empty):
        avg = query_df["Value"].mean()
        df.loc[(df['Value'] == 0.0) & (df['Labour Force Characteristics'] == row[0]) * (df["NAICS"] == row[1]) & (df["Gender"] == row[2]) & (df["Age Group"] == row[3]), "Value"] = avg

df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Date, Labour Force Characteristics, NAICS, Gender, Age Group, Value]
# Index: []

# %% [markdown]
# ### Multiply By The Scalar Value

# %%
df["Value"] = (df["Value"] * 1000).round(0)
df["Value"] = df["Value"].astype('int64')

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#       Date Labour Force Characteristics                                 NAICS  \
# 0     2000                     Employed  Accommodation and food services [72]
# 1     2000                     Employed  Accommodation and food services [72]
# 2     2000                     Employed  Accommodation and food services [72]
# 3     2000                     Employed  Accommodation and food services [72]
# 4     2000                     Employed  Accommodation and food services [72]
# ...    ...                          ...                                   ...
# 5707  2020                   Unemployed                        Utilities [22]
# 5708  2020                   Unemployed                        Utilities [22]
# 5709  2020                   Unemployed                        Utilities [22]
# 5710  2020                   Unemployed                        Utilities [22]
# 5711  2020                   Unemployed                        Utilities [22]
#
#        Gender          Age Group   Value
# 0     Females     15 to 24 years  235000
# 1     Females  15 years and over  558200
# 2     Females     25 to 54 years  285400
# 3     Females  55 years and over   37700
# 4       Males     15 to 24 years  160900
# ...       ...                ...     ...
# 5707  Females  55 years and over       0
# 5708    Males     15 to 24 years       0
# 5709    Males  15 years and over    2100
# 5710    Males     25 to 54 years    1743
# 5711    Males  55 years and over       0
#
# [5712 rows x 6 columns]

# %%
df.dtypes
# Out:
# Date                             int64
# Labour Force Characteristics    object
# NAICS                           object
# Gender                          object
# Age Group                       object
# Value                            int64
# dtype: object

# %% [markdown]
# ### Export To CSV

# %%
df.to_csv('data/cleaned_employment_by_industry.csv', index=False)
